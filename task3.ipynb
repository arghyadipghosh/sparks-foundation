# %% [markdown]
# # NAME - ARGHYADIP GHOSH
# # GRIP TASK - 3 ( THE SPARKS FOUNDATION)
# # TOPIC: "Create the Decision Tree classifier and visualize it graphically.The purpose is if we feed any new data to this classifier, it would be able topredict the right class accordingly. "

# %%
#import the library
import pandas as pd #data manipuation
import numpy as np  #linear algebra
import seaborn as sns  #stastics 
import matplotlib.pyplot as plt #visualzation
# %matplotlib inline
import warnings  #Warning

# %%
iris=pd.read_csv("Iris.csv") #loading the dataset

# %%
iris.head() #viewing the first 5 attributes of the dataset
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info() # checking the charecterictics of the attributes of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.shape # displaying the number of rows and columns of the dataset
# Out:
# (150, 6)

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
iris.isnull().sum()/100
# Out:
# Id               0.0
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %%
print(iris['Species'].value_counts())
sns.countplot(x="Species",data=iris)
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # BUILDING THE TEST AND TRAIN MODEL

# %%
from sklearn.model_selection import train_test_split
X= iris.iloc [:,1:-1]
Y= iris.iloc[:,-1]
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %% [markdown]
# # DEFINING THE DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier
lm= DecisionTreeClassifier(random_state=0)
lm.fit(X_train,Y_train)
print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %% [markdown]
# # CHECKING THE ACCURACY OF THE MODEL:

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
Y_train_pred=lm.predict(X_train)
Y_test_pred=lm.predict(X_test)
print("Train accuracy score:",accuracy_score(Y_train,Y_train_pred))
print("Test accuracy score:",accuracy_score(Y_test,Y_test_pred))
# Out:
# Train accuracy score: 1.0
# Test accuracy score: 0.9777777777777777

# %% [markdown]
# # VISUALISING THE DECISIONT

# %%
from sklearn.tree import plot_tree
plt.figure (figsize=(15,15))
plot_tree(lm,filled= True)
print()

# %% [markdown]
# ### Now let us define the Decision Tree Algorithm

# %%
# Defining the decision tree algorithm
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)

print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %% [markdown]
# ### Let us visualize the Decision Tree to understand it better.

# %%
# Install required libraries
# !pip install pydotplus
# !apt-get install graphviz -y

# %%
# Import necessary libraries for graph viz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# **You can now feed any new/test data to this classifer and it would be able to predict the right class accordingly.**
